# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar datos limpios
data_path = "../data/processed/cleaned_products.csv"
df = pd.read_csv(data_path)

# Análisis y visualización
print("Basic statistics:")
print(df.describe())

# Histograma de precios
plt.hist(df['price'], bins=20, edgecolor='black')
plt.title('Distribución de Precios')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.show()

# Productos más caros
print("Productos más caros:")
print(df.nlargest(5, 'price'))
# Out:
# Basic statistics:
#              price
# count     3.000000
# mean   1287.396667
# std      96.950059
# min    1223.990000
# 25%    1231.595000
# 50%    1239.200000
# 75%    1319.100000
# max    1399.000000
# Productos más caros:
#                title                                        description  \
# 1  Asus ROG Strix...  Asus ROG Strix GL702VM-GC146T, 17.3" FHD, Core...
# 0  Asus ZenBook U...  Asus ZenBook UX530UX-FY040T Blue, 15.6" FHD, C...
# 2      ThinkPad Yoga  12.5" Touch, Core i5 4200U, 8GB, 500GB + 16GB ...
#
#      price
# 1  1399.00
# 0  1239.20
# 2  1223.99
