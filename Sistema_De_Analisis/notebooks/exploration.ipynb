# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar datos limpios
data_path = "../data/processed/cleaned_products.csv"
df = pd.read_csv(data_path)

# Análisis y visualización
print("Basic statistics:")
print(df.describe())

# Histograma de precios
plt.hist(df['price'], bins=20, edgecolor='black')
plt.title('Distribución de Precios')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.show()

# Productos más caros
print("Productos más caros:")
print(df.nlargest(5, 'price'))
# Out:
# Basic statistics:
#              price
# count     3.000000
# mean    636.736667
# std     617.757293
# min      99.990000
# 25%     299.110000
# 50%     498.230000
# 75%     905.110000
# max    1311.990000
# Productos más caros:
#                title                                        description  \
# 1      ThinkPad X240  12.5", Core i5-4300U, 8GB, 240GB SSD, Win7 Pro...
# 2  Lenovo V510 Bl...  Lenovo V510 Black, 15.6" FHD, Core i3-7100U, 4...
# 0  Iconia B1-730H...      Black, 7", 1.6GHz Dual-Core, 8GB, Android 4.4
#
#      price
# 1  1311.99
# 2   498.23
# 0    99.99
