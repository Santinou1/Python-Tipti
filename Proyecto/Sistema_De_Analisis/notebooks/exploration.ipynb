# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar datos limpios
data_path = "../data/processed/cleaned_products.csv"
df = pd.read_csv(data_path)

# Análisis y visualización
print("Basic statistics:")
print(df.describe())

# Histograma de precios
plt.hist(df['price'], bins=20, edgecolor='black')
plt.title('Distribución de Precios')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.show()

# Productos más caros
print("Productos más caros:")
print(df.nlargest(5, 'price'))
# Out:
# Basic statistics:
#             price
# count    3.000000
# mean   513.333333
# std    201.328918
# min    300.000000
# 25%    420.000000
# 50%    540.000000
# 75%    620.000000
# max    700.000000
# Productos más caros:
#               title                                        description  price
# 1            Iphone                                              White  700.0
# 2  Acer Aspire 3...  Acer Aspire 3 A315-31 Black, 15.6" HD, Pentium...  540.0
# 0     ThinkPad X240  12.5", Core i5-4300U, 8GB, 240GB SSD, Win7 Pro...  300.0
